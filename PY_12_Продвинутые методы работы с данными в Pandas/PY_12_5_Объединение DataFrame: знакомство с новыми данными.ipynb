# %%
import pandas as pd

dates_db = pd.read_csv('data/movies_data/dates.csv')
movies_db = pd.read_csv('data/movies_data/movies.csv')
ratings1_db = pd.read_csv('data/movies_data/ratings1.csv')
ratings2_db = pd.read_csv('data/movies_data/ratings2.csv')

# %%
ratings1_db.nunique()
# Out:
# userId      274
# movieId    6219
# rating       10
# dtype: int64

# %%
dates_db['date'] = pd.to_datetime(dates_db['date'])
dates_db['date'].dt.year.value_counts()
# Out:
# date
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: count, dtype: int64

# %%
movies_db.nunique()
# Out:
# movieId    9742
# title      9737
# genres      951
# dtype: int64
