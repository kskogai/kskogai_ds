# %%
import pandas as pd

# Читаем файл melb_data.csv
melb_data = pd.read_csv('data/melb_data.csv', sep=',')

# %% [markdown]
# Агрегирующие методы
#
# Агрегирующим в Pandas называется метод, который для каждого столбца возвращает только одно значение — показатель (например, вычисление медианы, максимума, среднего и тд).

# %% [markdown]
# Основные агрегирующие методы:
#
# - .count() - количество непустых значений;
# - .mean() - среднее значение;
# - .min() - минимальное значение;
# - .max() - максимальное значение;
# - .var() - дисперсия;
# - .std() - стандартное отклонение;
# - .sum() - сумма;
# - .quantile(x) - квантиль уровня х;
# - .nunique() - число уникальных значений.

# %% [markdown]
# Если один из этих методов применить ко всему DataFrame, то в результате его работы будет получен объект типа Series, в котором в качестве индексов будут выступать наименования столбцов, а в качестве значений — статистический показатель. В случае применения метода к отдельному столбцу результатом вычислений станет число.

# %% [markdown]
# В каждый метод можно передать некоторые параметры, среди которых:
#
# - axis — определяет, подсчитывать параметр по строкам или по столбцам;
# - numeric_only — определяет, вычислять параметры только по числовым столбцам/строкам или нет (True/False).

# %%
# Вычисляем среднюю цену на объекты недвижимости
print(melb_data['Price'].mean())
# Out:
# 1075684.079455081

# %%
# Находим максимальное количество парковочных мест
print(melb_data['Car'].max())
# Out:
# 10.0

# %%
# Найдем общую прибыльность риэлторского бизнеса в Мельбурне и округлим результат до сотых
# Риэлторская ставка равна 12%
rate = 0.12
income = melb_data['Price'].sum() * rate
print(f'Total income of real estate agencies: {round(income, 2)}')
# Out:
# Total income of real estate agencies: 1752934775.88

# %%
# Вычислим, насколько медианная площадь территории отличается от ее среднего значения. Для этого
# вычислим модуль разницы между медианой и средним, и разделим результат на среднее,
# чтобы получить отклонение в долях

median_area = abs((melb_data['Landsize'].median() - melb_data['Landsize'].mean())/melb_data['Landsize'].mean())
print(median_area)

# Либо так
landsize_median = melb_data['Landsize'].median()
landsize_mean = melb_data['Landsize'].mean()
print(abs(landsize_median-landsize_mean)/landsize_mean)
# Out:
# 0.21205713983546193
# 0.21205713983546193

# %% [markdown]
# В результате получим долю отклонения медианы от среднего значения. Умножив результат на 100, получим его в процентах. Отклонение медианы от среднего значения на 21% является довольно большим, и это повод задуматься над тем, чтобы исследовать признак на наличие аномалий.

# %% [markdown]
# Модальное значение
#
# Отдельный интерес представляет показатель моды — самого распространенного значения в столбце. Он вычисляется с помощью метода mode().
#
# Модальных значений может быть несколько, то есть несколько значений могут встречаться одинаковое количество раз. Поэтому метод mode(), в отличие от агрегирующих методов, возвращает не одно число, а серию.

# %%
# Вычисляем, какое число комнат чаще всего представлено на рынке недвижимости
print(melb_data['Rooms'].mode())
# Out:
# 0    3
# Name: Rooms, dtype: int64

# %% [markdown]
# Метод mode() может быть использован не только с числовыми столбцами, но и со столбцами типа object. Например, с помощью следующего кода можно найти наиболее распространенное название района.

# %%
print(melb_data['Regionname'].mode())
# Out:
# 0    Southern Metropolitan
# Name: Regionname, dtype: object

# %%
# Вычислим, чему равно максимальное количество домов на продажу в районе
print(melb_data['Propertycount'].max())
# Out:
# 21650.0

# %%
# Находим, чему равно стандартное отклонение (разброс) расстояния от центра города до объекта недвижимости
print(round(melb_data['Distance'].std()))
# Out:
# 6

# %%
# Чему равно отклонение (в процентах) медианного значения площади здания от его среднего значения?
building_size_median = melb_data['BuildingArea'].median()
building_size_mean = melb_data['BuildingArea'].mean()
print(round(abs((building_size_median-building_size_mean)/building_size_mean) * 100))
# Out:
# 10

# %%
# Сколько спален чаще всего встречается в домах в Мельбурне?
print(melb_data['Bedroom'].mode())
# Out:
# 0    3.0
# Name: Bedroom, dtype: float64
